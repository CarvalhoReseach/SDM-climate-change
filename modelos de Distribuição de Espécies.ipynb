# %%
library(dismo)
library(raster)
library(maptools)
library(sf)
library(corrplot)
library(ggfortify)
library(SSDM)
# Out:
# Loading required package: raster
#
# Loading required package: sp
#
# Checking rgeos availability: TRUE
#
# Linking to GEOS 3.8.0, GDAL 2.4.2, PROJ 5.2.0
#
# WARNING: different compile-time and runtime versions for GEOS found:
#
# Linked against: 3.8.0-CAPI-1.13.1  compiled against: 3.7.1-CAPI-1.11.1
#
# It is probably a good idea to reinstall sf, and maybe rgeos and rgdal too
#
# corrplot 0.84 loaded
#
# Loading required package: ggplot2
#
# Welcome to the SSDM package, you can launch the graphical user interface by typing gui() in the console.
#
#
# Attaching package: ‘SSDM’
#
#
# The following object is masked from ‘package:dismo’:
#
#     evaluate

# %%
files<-list.files('/home/eduardo/projetos/conservacao_de_plantas_mudancas_climaticas/data/models/preditor/',pattern='.tif')
caminhos<-paste('/home/eduardo/projetos/conservacao_de_plantas_mudancas_climaticas/data/models/preditor/',files,sep='')

fil<-list.files('/home/eduardo/projetos/conservacao_de_plantas_mudancas_climaticas/data/species_ocurrence/processed',pattern='.csv')
cam<-paste('/home/eduardo/projetos/conservacao_de_plantas_mudancas_climaticas/data/species_ocurrence/processed/',fil,sep='')

# %%
env<-load_var(path = "/home/eduardo/projetos/conservacao_de_plantas_mudancas_climaticas/data/models/preditor/", files = NULL, format = ".tif",categorical = NULL, Norm = TRUE, tmp = TRUE, verbose = FALSE,GUI = FALSE)
# Out:
# NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# ...

# %%
for (i in 1:length(fil)){
    
    occ <- load_occ(path= '/home/eduardo/projetos/conservacao_de_plantas_mudancas_climaticas/data/species_ocurrence/processed/',file=fil[i], env,verbose=FALSE, Xcol = 'longitude', Ycol = 'latitude', sep = ',')

    GLM<- modelling('GLM',occ, env, Xcol = 'longitude', Ycol = 'latitude', metric='TSS',verbose = FALSE)
    evaluate<-GLM@evaluation
    import<-GLM@variable.importance
    resumo <-merge(evaluate, import)
    nome_resumo <- paste('/home/eduardo/projetos/conservacao_de_plantas_mudancas_climaticas/data/models/response/glm/','glm_eval_import_',fil[i],sep='')
    write.csv(resumo, nome_resumo)
    
    GAM <- modelling('GAM', occ, env, Xcol = 'longitude', Ycol = 'latitude', metric='TSS',verbose = FALSE)
    evaluate<-GAM@evaluation
    import<-GAM@variable.importance
    resumo <-merge(evaluate, import)  
    nome_resumo <- paste('/home/eduardo/projetos/conservacao_de_plantas_mudancas_climaticas/data/models/response/gam/','gam_eval_import_',fil[i],sep='')
    write.csv(resumo, nome_resumo)
    
    MARS <- modelling('MARS', occ, env, Xcol = 'longitude', Ycol = 'latitude', metric='TSS',verbose = FALSE)
    evaluate<-MARS@evaluation
    import<-MARS@variable.importance
    resumo <-merge(evaluate, import)
    nome_resumo <- paste('/home/eduardo/projetos/conservacao_de_plantas_mudancas_climaticas/data/models/response/mars/','mars_eval_import_',fil[i],sep='')
    write.csv(resumo, nome_resumo)
    
    GBM <- modelling('GBM', occ, env, Xcol = 'longitude', Ycol = 'latitude', metric='TSS',verbose = FALSE)
    evaluate<-GBM@evaluation
    import<-GBM@variable.importance
    resumo <-merge(evaluate, import)
    nome_resumo <- paste('/home/eduardo/projetos/conservacao_de_plantas_mudancas_climaticas/data/models/response/gbm/','gbm_eval_import_',fil[i],sep='')
    write.csv(resumo, nome_resumo)
    
    CTA <- modelling('CTA', occ, env, Xcol = 'longitude', Ycol = 'latitude', metric='TSS',verbose = FALSE)
    evaluate<-CTA@evaluation
    import<-CTA@variable.importance
    resumo <-merge(evaluate, import)
    nome_resumo <- paste('/home/eduardo/projetos/conservacao_de_plantas_mudancas_climaticas/data/models/response/cta/','cta_eval_import_',fil[i],sep='')
    write.csv(resumo, nome_resumo)
    
    RF <- modelling('RF', occ, env, Xcol = 'longitude', Ycol = 'latitude', metric='TSS',verbose = FALSE)
    evaluate<-RF@evaluation
    import<-RF@variable.importance
    resumo <-merge(evaluate, import)
    nome_resumo <- paste('/home/eduardo/projetos/conservacao_de_plantas_mudancas_climaticas/data/models/response/rf/','rf_eval_import_',fil[i],sep='')
    write.csv(resumo, nome_resumo)
    
    MAXENT <- modelling('MAXENT', occ, env, Xcol = 'longitude', Ycol = 'latitude', metric='TSS', verbose = FALSE)
    evaluate<-MAXENT@evaluation
    import<-MAXENT@variable.importance
    resumo <-merge(evaluate, import)
    nome_resumo <- paste('/home/eduardo/projetos/conservacao_de_plantas_mudancas_climaticas/data/models/response/maxent/','maxent_eval_import_',fil[i],sep='')
    write.csv(resumo, nome_resumo)
    
    ANN <- modelling('ANN', occ, env, Xcol = 'longitude', Ycol = 'latitude',metric='TSS', verbose = FALSE)
    evaluate<-ANN@evaluation
    import<-ANN@variable.importance
    resumo <-merge(evaluate, import)
    nome_resumo <- paste('/home/eduardo/projetos/conservacao_de_plantas_mudancas_climaticas/data/models/response/ann/','ann_eval_import_',fil[i],sep='')
    write.csv(resumo, nome_resumo)
    
    SVM <- modelling('SVM', occ, env, Xcol = 'longitude', Ycol = 'latitude', metric='TSS', verbose = FALSE)
    evaluate<-SVM@evaluation
    import<-SVM@variable.importance
    resumo <-merge(evaluate, import)
    nome_resumo <- paste('/home/eduardo/projetos/conservacao_de_plantas_mudancas_climaticas/data/models/response/svm/','svm_eval_import_',fil[i],sep='')
    write.csv(resumo, nome_resumo)   
}
